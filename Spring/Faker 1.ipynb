# %%
#pip install Faker

# %%
from faker import Faker
import random 
import pandas as pd
from datetime import datetime, timedelta
from datetime import date
import numpy as np

def generate_demographic_data(num_records):
    fake = Faker('en_US')
    Faker.seed(42)
    random.seed(42)
    demographic_data = []
    for i in range(1, num_records + 1):
        demographic_data.append({
            'ID': i,
            'Age': random.randint(18, 80),
            'Gender': random.choice(['Male', 'Female', 'Other']),
            'Location': fake.city(), #use predefined list instead, random choice 
            'Email': fake.email(), 
        })
    return pd.DataFrame(demographic_data)
# can add more features, and make income dependent on other factors besides just age

# %%
demo_df = generate_demographic_data(num_records = 1000)
demo_df
# Out:
#        ID  Age  Gender           Location                        Email
# 0       1   58    Male   North Judithbury     donaldgarcia@example.net
# 1       2   19   Other     New Roberttown  robinsonwilliam@example.org
# 2       3   35    Male         Lake Debra        lrobinson@example.com
# 3       4   32    Male  Port Lindachester         joshua35@example.org
# 4       5   65    Male    South Colinstad        lindsay78@example.org
# ..    ...  ...     ...                ...                          ...
# 995   996   49   Other     South Samantha      kaylarhodes@example.com
# 996   997   60  Female     West Erinville          gbrooks@example.com
# 997   998   20    Male  North Christopher          rgibson@example.net
# 998   999   43   Other     West Taramouth         stacey92@example.org
# 999  1000   21    Male     Port Dawnmouth       manningamy@example.net
#
# [1000 rows x 5 columns]

# %%
def generate_income_by_age(age):
    if age < 25:
        return random.randint(20000, 50000)  # Young adults
    elif 25 <= age <= 40:
        return random.randint(50000, 100000)  # Mid-career
    elif 41 <= age <= 60:
        return random.randint(70000, 150000)  # Established professionals
    else:
        return random.randint(30000, 80000) 

demo_df['Income'] = demo_df.apply(lambda row: generate_income_by_age(row['Age']), axis=1)
demo_df
# Out:
#        ID  Age  Gender           Location                        Email  Income
# 0       1   58    Male   North Judithbury     donaldgarcia@example.net   96794
# 1       2   19   Other     New Roberttown  robinsonwilliam@example.org   29876
# 2       3   35    Male         Lake Debra        lrobinson@example.com   63843
# 3       4   32    Male  Port Lindachester         joshua35@example.org   58993
# 4       5   65    Male    South Colinstad        lindsay78@example.org   46745
# ..    ...  ...     ...                ...                          ...     ...
# 995   996   49   Other     South Samantha      kaylarhodes@example.com  132580
# 996   997   60  Female     West Erinville          gbrooks@example.com  112415
# 997   998   20    Male  North Christopher          rgibson@example.net   28128
# 998   999   43   Other     West Taramouth         stacey92@example.org   70895
# 999  1000   21    Male     Port Dawnmouth       manningamy@example.net   28545
#
# [1000 rows x 6 columns]

# %%
#Viewership Data 
def generate_fake_viewership(demo_df, num_viewership_records, network_to_shows_genres, network_weights):
    fake = Faker('en_US')
    Faker.seed(42)
    random.seed(42)
    ids = demo_df['ID'].tolist()
    
    start_date = datetime(2022, 1,1, 0, 0, 0)
    end_date = datetime(2024, 12, 31, 21, 59, 59)

    viewership_data = []
    for _ in range(num_viewership_records):
        id_ = random.choice(ids)
        time_started = fake.date_time_between(start_date = start_date, end_date = end_date)
        duration = timedelta(minutes = fake.random_int(min=6, max= 120))
        time_ended = time_started + duration 
        
         # Select a network based on weights
        network = random.choices(list(network_to_shows_genres.keys()), weights=network_weights, k=1)[0]
        
        # Select a show and its corresponding genre
        show, genre = random.choice(list(network_to_shows_genres[network].items()))
        
        viewership_data.append({
            'ID': id_, 
            'Time Started': time_started,
            'Time Ended': time_ended, 
            'Show Name': show,
            'Network': network, 
            'Genre': genre
        })
    
    viewership_df = pd.DataFrame(viewership_data)
    return viewership_df

# %%
# network_to_shows = {
#     'Lime Light': ['Fashion Frenzy: The Runway Wars', 'Home Makeover Rescue', 'Celebrity Chefs Showdown'],
#     'Pulse': ['Edge of Extinction', 'Highway Heist', 'Stormfront: The Final Mission'],
#     'ChillStream': ['Oceans Untamed: The Deep Unknown', 'Ancient Civilizations Uncovered', 'World Wonders: Nature''s Marvels'],
#     'RetroReel': ['Vintage Noir: Tale of the 50s', 'Hollywood Gold: The Best of the Silver Screen', 'The Golden Age of Television'],
#     'CineQuest': ['The Forgotten Kingdom', 'Unwritten Laws', 'Echoes of the Past'],
# }

# network_to_genres = {
#     'Lime Light': ['Reality TV', 'Lifestyle'],
#     'Pulse': ['Action', 'Thriller', 'Adventure'],
#     'ChillStream': ['Documentaries', 'Nature', 'Travel'],
#     'RetroReel': ['Classic Films'],
#     'CineQuest': ['Premium Films'],
# }

network_to_shows_genres = {
    'Lime Light': {
        'Fashion Frenzy: The Runway Wars': 'Reality TV',
        'Home Makeover Rescue': 'Lifestyle',
        'Celebrity Chefs Showdown': 'Reality TV',
    },
    'Pulse': {
        'Edge of Extinction': 'Action',
        'Highway Heist': 'Thriller',
        'Stormfront: The Final Mission': 'Adventure',
    },
    'ChillStream': {
        'Oceans Untamed: The Deep Unknown': 'Nature',
        'Ancient Civilizations Uncovered': 'Documentaries',
        'World Wonders: Nature\'s Marvels': 'Travel',
    },
    'RetroReel': {
        'Vintage Noir: Tale of the 50s': 'Classic Films',
        'Hollywood Gold: The Best of the Silver Screen': 'Classic Films',
        'The Golden Age of Television': 'Classic Films',
    },
    'CineQuest': {
        'The Forgotten Kingdom': 'Premium Films',
        'Unwritten Laws': 'Premium Films',
        'Echoes of the Past': 'Premium Films',
    },
}

network_weights = [20, 40, 20, 10, 10] #can adjust 
num_viewership_records = 100000
viewership_df = generate_fake_viewership(demo_df, num_viewership_records, network_to_shows_genres, network_weights)

viewership_df

#create histogram, total minutes viewed
# Out:
#         ID        Time Started          Time Ended  \
# 0      655 2024-09-20 07:33:32 2024-09-20 07:53:32
# 1      282 2022-02-08 20:28:06 2022-02-08 22:08:06
# 2      755 2023-03-04 05:50:10 2023-03-04 06:27:10
# 3      914 2022-12-13 17:53:58 2022-12-13 18:16:58
# 4      433 2022-06-09 05:17:49 2022-06-09 06:49:49
# ...    ...                 ...                 ...
# 99995  685 2023-10-17 07:12:22 2023-10-17 07:39:22
# 99996  701 2022-11-03 16:52:05 2022-11-03 18:21:05
# 99997  653 2022-03-18 08:59:53 2022-03-18 09:53:53
# 99998  714 2024-01-21 03:44:46 2024-01-21 04:37:46
# 99999   16 2022-12-10 18:23:39 2022-12-10 20:00:39
#
#                              Show Name     Network       Genre
# 0             Celebrity Chefs Showdown  Lime Light  Reality TV
# 1                   Edge of Extinction       Pulse      Action
# 2             Celebrity Chefs Showdown  Lime Light  Reality TV
# 3        Stormfront: The Final Mission       Pulse   Adventure
# 4      Fashion Frenzy: The Runway Wars  Lime Light  Reality TV
# ...                                ...         ...         ...
# 99995             Home Makeover Rescue  Lime Light   Lifestyle
# 99996  Fashion Frenzy: The Runway Wars  Lime Light  Reality TV
# 99997               Edge of Extinction       Pulse      Action
# 99998  Fashion Frenzy: The Runway Wars  Lime Light  Reality TV
# 99999  Fashion Frenzy: The Runway Wars  Lime Light  Reality TV
#
# [100000 rows x 6 columns]

# %% [markdown]
# ## Online Content Data

# %% [markdown]
# First, create subset of fake urls, which we will then sample from randomly in generate_fake_online_content()

# %%
shows = [
    "Fashion Frenzy: The Runway Wars",
    "Home Makeover Rescue",
    "Celebrity Chefs Showdown",
    "Style Seekers: Global Trends",
    "The Perfect Party Planner",
    "Behind the Glam: Celebrity Secrets",
    "Living Large: Luxury Homes Edition",
    "Fitness Gurus: Transformations",
    "Destination Wedding Dreams",
    "Extreme Makeovers: House Flips",
    "Edge of Extinction",
    "Highway Heist",
    "Stormfront: The Final Mission",
    "Deep Waters: Submarine Showdown",
    "Midnight Pursuit",
    "Target Locked",
    "Chasing Shadows: Elite Unit",
    "Blood Oath: Vigilante Justice",
    "Flight Risk",
    "The Last Outpost",
    "Oceans Untamed: The Deep Unknown",
    "Ancient Civilizations Uncovered",
    "World Wonders: Nature's Marvels",
    "The Amazon Trail: A Journey Through the Rainforest",
    "Surviving Antarctica: The Final Frontier",
    "Wildlife Warriors: Protectors of the Endangered",
    "Unseen Worlds: Microscopic Marvels",
    "Nomads of the North: Life in the Arctic",
    "Mount Everest: Beyond the Summit",
    "Wonders of the Coral Reef",
    "Vintage Noir: Tales of the 50s",
    "Hollywood Gold: The Best of the Silver Screen",
    "The Golden Age of Television",
    "Classic Cartoons Rewind",
    "Heroes of the West: Old Cowboy Adventures",
    "The Big Picture: Cinema’s Finest Years",
    "Love in Black and White: Romantic Classics",
    "Retro Sci-Fi: Space and Beyond",
    "Timeless Thrillers: Hitchcock’s Legacy",
    "1950s Sitcom Showcase",
    "The Forgotten Kingdom",
    "Unwritten Laws",
    "Echoes of the Past",
    "Shattered Mirror: A Tale of Betrayal",
    "Lies Beneath the Surface",
    "After the Storm: A Family’s Battle",
    "In the Shadow of Giants",
    "Fallen Crown: The Battle for the Throne",
    "Last Sunset: A Dystopian Love Story",
    "Whispers in the Dark"]

#start = "www"
subdomains = ["www", "stream", "watch", "view", "media", "online", "hub"]
suffixes = [
    "",
    "-season-1",
    "-exclusive",
    "-special",
    "-preview",
    f"?ref=source{random.randint(1, 10)}",
    f"?utm_campaign=ad{random.randint(1, 100)}",
    "-free-trial",
    "-new",
    "-episode-guide",
]
domains = ["example.com", "tvnetwork.com", "streamit.net", "watchhub.org", "myshow.tv"]

# Generate multiple variations per show
def generate_url_variations(show, num_variations=5):
    base_url = show.lower().replace(" ", "-").replace(":", "").replace("’", "").replace("'", "").replace(",", "")
    variations = []
    for _ in range(num_variations):
        subdomain = random.choice(subdomains)
        suffix = random.choice(suffixes)
        domain = random.choice(domains)
        variations.append(f"{subdomain}.{domain}/{base_url}{suffix}")
    return variations

# Generate URLs for all shows
all_urls = []
for show in shows:
    all_urls.extend(generate_url_variations(show, num_variations=random.randint(5,10)))  # Up to 5 variations per show

# Print a sample of the generated URLs
for url in random.sample(all_urls, 20):  # Show 20 random samples
    print(url)

# Total number of URLs
print(f"Total URLs generated: {len(all_urls)}")
# Out:
# stream.watchhub.org/whispers-in-the-dark-special
# online.tvnetwork.com/the-golden-age-of-television-exclusive
# media.tvnetwork.com/destination-wedding-dreams-free-trial
# watch.example.com/chasing-shadows-elite-unit
# view.myshow.tv/the-big-picture-cinemas-finest-years-preview
# media.myshow.tv/deep-waters-submarine-showdown-season-1
# online.myshow.tv/whispers-in-the-dark?ref=source2
# media.myshow.tv/echoes-of-the-past-special
# online.myshow.tv/ancient-civilizations-uncovered-new
# online.tvnetwork.com/timeless-thrillers-hitchcocks-legacy-special
# stream.myshow.tv/blood-oath-vigilante-justice-preview
# watch.myshow.tv/fitness-gurus-transformations?ref=source2
# hub.streamit.net/home-makeover-rescue-special
# hub.example.com/after-the-storm-a-familys-battle?utm_campaign=ad33
# www.watchhub.org/hollywood-gold-the-best-of-the-silver-screen?utm_campaign=ad33
# stream.example.com/shattered-mirror-a-tale-of-betrayal-free-trial
# online.streamit.net/unseen-worlds-microscopic-marvels?ref=source2
# hub.example.com/celebrity-chefs-showdown-new
# watch.tvnetwork.com/timeless-thrillers-hitchcocks-legacy?ref=source2
# hub.streamit.net/fallen-crown-the-battle-for-the-throne-season-1
# Total URLs generated: 360

# %%
all_urls
# Out:
# ['watch.example.com/fashion-frenzy-the-runway-wars?ref=source2',
#  'media.tvnetwork.com/fashion-frenzy-the-runway-wars-free-trial',
#  'view.myshow.tv/fashion-frenzy-the-runway-wars-preview',
#  'media.streamit.net/fashion-frenzy-the-runway-wars-new',
#  'stream.watchhub.org/fashion-frenzy-the-runway-wars-special',
#  'stream.watchhub.org/fashion-frenzy-the-runway-wars-episode-guide',
#  'stream.watchhub.org/fashion-frenzy-the-runway-wars-exclusive',
#  'online.watchhub.org/home-makeover-rescue?ref=source2',
#  'stream.tvnetwork.com/home-makeover-rescue?ref=source2',
#  'hub.streamit.net/home-makeover-rescue-special',
#  'www.example.com/home-makeover-rescue-new',
#  'hub.watchhub.org/home-makeover-rescue-episode-guide',
#  'hub.streamit.net/home-makeover-rescue?utm_campaign=ad33',
#  'view.watchhub.org/home-makeover-rescue-episode-guide',
#  'watch.example.com/celebrity-chefs-showdown?ref=source2',
#  'view.tvnetwork.com/celebrity-chefs-showdown?ref=source2',
#  'hub.myshow.tv/celebrity-chefs-showdown?ref=source2',
#  'online.watchhub.org/celebrity-chefs-showdown-special',
#  'hub.watchhub.org/celebrity-chefs-showdown-preview',
#  'online.myshow.tv/celebrity-chefs-showdown-new',
#  'www.streamit.net/celebrity-chefs-showdown-exclusive',
#  'hub.example.com/celebrity-chefs-showdown-new',
#  'stream.myshow.tv/celebrity-chefs-showdown-episode-guide',
#  'online.tvnetwork.com/style-seekers-global-trends-new',
#  'media.myshow.tv/style-seekers-global-trends-preview',
#  'stream.streamit.net/style-seekers-global-trends?utm_campaign=ad33',
#  'www.myshow.tv/style-seekers-global-trends-free-trial',
#  'media.watchhub.org/style-seekers-global-trends?ref=source2',
#  'watch.tvnetwork.com/style-seekers-global-trends?ref=source2',
#  'view.tvnetwork.com/style-seekers-global-trends?ref=source2',
#  'media.watchhub.org/style-seekers-global-trends',
#  'online.myshow.tv/style-seekers-global-trends-preview',
#  'www.tvnetwork.com/style-seekers-global-trends-special',
#  'www.streamit.net/the-perfect-party-planner?ref=source2',
#  'hub.example.com/the-perfect-party-planner',
#  'hub.example.com/the-perfect-party-planner-new',
#  'www.myshow.tv/the-perfect-party-planner?ref=source2',
#  'stream.streamit.net/the-perfect-party-planner-new',
#  'hub.streamit.net/the-perfect-party-planner-special',
#  'online.myshow.tv/the-perfect-party-planner?utm_campaign=ad33',
#  'view.example.com/the-perfect-party-planner-special',
#  'view.watchhub.org/behind-the-glam-celebrity-secrets-free-trial',
#  'media.myshow.tv/behind-the-glam-celebrity-secrets-new',
#  'view.streamit.net/behind-the-glam-celebrity-secrets-season-1',
#  'hub.example.com/behind-the-glam-celebrity-secrets-exclusive',
#  'www.streamit.net/behind-the-glam-celebrity-secrets-special',
#  'online.tvnetwork.com/behind-the-glam-celebrity-secrets-special',
#  'view.streamit.net/behind-the-glam-celebrity-secrets-preview',
#  'www.example.com/living-large-luxury-homes-edition-special',
#  'online.example.com/living-large-luxury-homes-edition-episode-guide',
#  'media.streamit.net/living-large-luxury-homes-edition-season-1',
#  'view.watchhub.org/living-large-luxury-homes-edition-special',
#  'media.watchhub.org/living-large-luxury-homes-edition-free-trial',
#  'stream.example.com/living-large-luxury-homes-edition-preview',
#  'online.streamit.net/fitness-gurus-transformations-preview',
#  'watch.myshow.tv/fitness-gurus-transformations-special',
#  'view.streamit.net/fitness-gurus-transformations?ref=source2',
#  'watch.watchhub.org/fitness-gurus-transformations-exclusive',
#  'view.streamit.net/fitness-gurus-transformations-season-1',
#  'watch.myshow.tv/fitness-gurus-transformations?ref=source2',
#  'watch.example.com/destination-wedding-dreams-exclusive',
#  'media.tvnetwork.com/destination-wedding-dreams-free-trial',
#  'hub.myshow.tv/destination-wedding-dreams-special',
#  'hub.myshow.tv/destination-wedding-dreams-special',
#  'view.example.com/destination-wedding-dreams?ref=source2',
#  'view.example.com/destination-wedding-dreams-new',
#  'media.watchhub.org/extreme-makeovers-house-flips-episode-guide',
#  'media.myshow.tv/extreme-makeovers-house-flips-episode-guide',
#  'www.streamit.net/extreme-makeovers-house-flips-special',
#  'view.streamit.net/extreme-makeovers-house-flips-new',
#  'online.watchhub.org/extreme-makeovers-house-flips-season-1',
#  'view.example.com/extreme-makeovers-house-flips-episode-guide',
#  'view.tvnetwork.com/extreme-makeovers-house-flips-new',
#  'stream.streamit.net/extreme-makeovers-house-flips?utm_campaign=ad33',
#  'watch.tvnetwork.com/extreme-makeovers-house-flips-season-1',
#  'view.watchhub.org/extreme-makeovers-house-flips-free-trial',
#  'watch.example.com/edge-of-extinction-preview',
#  'www.watchhub.org/edge-of-extinction-new',
#  'media.example.com/edge-of-extinction?ref=source2',
#  'watch.example.com/edge-of-extinction-episode-guide',
#  'stream.tvnetwork.com/edge-of-extinction-special',
#  'online.streamit.net/highway-heist-preview',
#  'hub.tvnetwork.com/highway-heist-preview',
#  'view.myshow.tv/highway-heist-special',
#  'www.tvnetwork.com/highway-heist-new',
#  'online.streamit.net/highway-heist-exclusive',
#  'www.myshow.tv/highway-heist-exclusive',
#  'online.streamit.net/highway-heist?ref=source2',
#  'media.streamit.net/highway-heist',
#  'watch.streamit.net/stormfront-the-final-mission?ref=source2',
#  'view.tvnetwork.com/stormfront-the-final-mission?utm_campaign=ad33',
#  'view.tvnetwork.com/stormfront-the-final-mission-preview',
#  'stream.watchhub.org/stormfront-the-final-mission-free-trial',
#  'hub.tvnetwork.com/stormfront-the-final-mission-episode-guide',
#  'stream.myshow.tv/stormfront-the-final-mission?utm_campaign=ad33',
#  'media.example.com/stormfront-the-final-mission-preview',
#  'hub.tvnetwork.com/stormfront-the-final-mission-new',
#  'watch.tvnetwork.com/stormfront-the-final-mission',
#  'watch.myshow.tv/stormfront-the-final-mission',
#  'watch.tvnetwork.com/deep-waters-submarine-showdown-exclusive',
#  'watch.tvnetwork.com/deep-waters-submarine-showdown-free-trial',
#  'media.myshow.tv/deep-waters-submarine-showdown-season-1',
#  'view.streamit.net/deep-waters-submarine-showdown?ref=source2',
#  'media.watchhub.org/deep-waters-submarine-showdown-preview',
#  'media.example.com/deep-waters-submarine-showdown-episode-guide',
#  'watch.tvnetwork.com/deep-waters-submarine-showdown-free-trial',
#  'view.watchhub.org/deep-waters-submarine-showdown-preview',
#  'view.streamit.net/deep-waters-submarine-showdown-preview',
#  'stream.myshow.tv/midnight-pursuit-preview',
#  'stream.myshow.tv/midnight-pursuit',
#  'view.example.com/midnight-pursuit?ref=source2',
#  'stream.example.com/midnight-pursuit-season-1',
#  'hub.example.com/midnight-pursuit?ref=source2',
#  'hub.example.com/midnight-pursuit-new',
#  'stream.tvnetwork.com/target-locked-episode-guide',
#  'online.tvnetwork.com/target-locked-exclusive',
#  'watch.tvnetwork.com/target-locked-special',
#  'view.example.com/target-locked-season-1',
#  'www.watchhub.org/target-locked?ref=source2',
#  'hub.tvnetwork.com/target-locked?ref=source2',
#  'watch.tvnetwork.com/target-locked-special',
#  'watch.example.com/chasing-shadows-elite-unit',
#  'stream.example.com/chasing-shadows-elite-unit-new',
#  'view.watchhub.org/chasing-shadows-elite-unit?ref=source2',
#  'online.tvnetwork.com/chasing-shadows-elite-unit',
#  'stream.watchhub.org/chasing-shadows-elite-unit-exclusive',
#  'stream.watchhub.org/blood-oath-vigilante-justice',
#  'watch.example.com/blood-oath-vigilante-justice?utm_campaign=ad33',
#  'hub.myshow.tv/blood-oath-vigilante-justice-episode-guide',
#  'www.streamit.net/blood-oath-vigilante-justice-exclusive',
#  'www.tvnetwork.com/blood-oath-vigilante-justice',
#  'view.tvnetwork.com/blood-oath-vigilante-justice?ref=source2',
#  'stream.myshow.tv/blood-oath-vigilante-justice-preview',
#  'stream.watchhub.org/blood-oath-vigilante-justice-preview',
#  'www.myshow.tv/flight-risk-exclusive',
#  'online.example.com/flight-risk-preview',
#  'hub.myshow.tv/flight-risk-exclusive',
#  'media.watchhub.org/flight-risk-new',
#  'watch.myshow.tv/flight-risk-episode-guide',
#  'view.myshow.tv/flight-risk',
#  'online.watchhub.org/flight-risk-free-trial',
#  'view.myshow.tv/flight-risk?utm_campaign=ad33',
#  'stream.myshow.tv/flight-risk',
#  'media.streamit.net/flight-risk-exclusive',
#  'watch.streamit.net/the-last-outpost',
#  'www.myshow.tv/the-last-outpost?utm_campaign=ad33',
#  'stream.myshow.tv/the-last-outpost-preview',
#  'media.streamit.net/the-last-outpost',
#  'watch.streamit.net/the-last-outpost-preview',
#  'www.streamit.net/oceans-untamed-the-deep-unknown-free-trial',
#  'watch.streamit.net/oceans-untamed-the-deep-unknown',
#  'media.tvnetwork.com/oceans-untamed-the-deep-unknown-free-trial',
#  'online.streamit.net/oceans-untamed-the-deep-unknown-preview',
#  'view.tvnetwork.com/oceans-untamed-the-deep-unknown-preview',
#  'online.example.com/oceans-untamed-the-deep-unknown-free-trial',
#  'online.tvnetwork.com/ancient-civilizations-uncovered-episode-guide',
#  'online.streamit.net/ancient-civilizations-uncovered-preview',
#  'view.myshow.tv/ancient-civilizations-uncovered-special',
#  'online.myshow.tv/ancient-civilizations-uncovered-new',
#  'view.tvnetwork.com/ancient-civilizations-uncovered-exclusive',
#  'media.streamit.net/world-wonders-natures-marvels-episode-guide',
#  'stream.tvnetwork.com/world-wonders-natures-marvels',
#  'stream.myshow.tv/world-wonders-natures-marvels',
#  'online.example.com/world-wonders-natures-marvels-preview',
#  'www.watchhub.org/world-wonders-natures-marvels?ref=source2',
#  'view.myshow.tv/world-wonders-natures-marvels?utm_campaign=ad33',
#  'online.myshow.tv/world-wonders-natures-marvels-free-trial',
#  'media.myshow.tv/the-amazon-trail-a-journey-through-the-rainforest?ref=source2',
#  'online.streamit.net/the-amazon-trail-a-journey-through-the-rainforest-special',
#  'hub.watchhub.org/the-amazon-trail-a-journey-through-the-rainforest-free-trial',
#  'media.watchhub.org/the-amazon-trail-a-journey-through-the-rainforest-preview',
#  'www.tvnetwork.com/the-amazon-trail-a-journey-through-the-rainforest?ref=source2',
#  'stream.example.com/the-amazon-trail-a-journey-through-the-rainforest-free-trial',
#  'online.watchhub.org/the-amazon-trail-a-journey-through-the-rainforest?ref=source2',
#  'www.example.com/the-amazon-trail-a-journey-through-the-rainforest?ref=source2',
#  'view.tvnetwork.com/surviving-antarctica-the-final-frontier-special',
#  'www.watchhub.org/surviving-antarctica-the-final-frontier-new',
#  'online.tvnetwork.com/surviving-antarctica-the-final-frontier-season-1',
#  'watch.tvnetwork.com/surviving-antarctica-the-final-frontier-preview',
#  'www.tvnetwork.com/surviving-antarctica-the-final-frontier-season-1',
#  'media.myshow.tv/surviving-antarctica-the-final-frontier-episode-guide',
#  'media.myshow.tv/wildlife-warriors-protectors-of-the-endangered',
#  'hub.example.com/wildlife-warriors-protectors-of-the-endangered',
#  'watch.streamit.net/wildlife-warriors-protectors-of-the-endangered-special',
#  'watch.example.com/wildlife-warriors-protectors-of-the-endangered-season-1',
#  'online.myshow.tv/wildlife-warriors-protectors-of-the-endangered-episode-guide',
#  'online.streamit.net/unseen-worlds-microscopic-marvels?ref=source2',
#  'www.myshow.tv/unseen-worlds-microscopic-marvels?ref=source2',
#  'stream.example.com/unseen-worlds-microscopic-marvels-season-1',
#  'www.tvnetwork.com/unseen-worlds-microscopic-marvels-preview',
#  'online.myshow.tv/unseen-worlds-microscopic-marvels-free-trial',
#  'online.example.com/nomads-of-the-north-life-in-the-arctic?ref=source2',
#  'watch.tvnetwork.com/nomads-of-the-north-life-in-the-arctic?utm_campaign=ad33',
#  'view.watchhub.org/nomads-of-the-north-life-in-the-arctic?utm_campaign=ad33',
#  'media.myshow.tv/nomads-of-the-north-life-in-the-arctic-preview',
#  'www.myshow.tv/nomads-of-the-north-life-in-the-arctic-exclusive',
#  'stream.myshow.tv/nomads-of-the-north-life-in-the-arctic-episode-guide',
#  'watch.tvnetwork.com/mount-everest-beyond-the-summit-preview',
#  'stream.watchhub.org/mount-everest-beyond-the-summit-special',
#  'hub.myshow.tv/mount-everest-beyond-the-summit-special',
#  'www.example.com/mount-everest-beyond-the-summit-new',
#  'online.watchhub.org/mount-everest-beyond-the-summit-new',
#  'stream.watchhub.org/mount-everest-beyond-the-summit-preview',
#  'media.streamit.net/mount-everest-beyond-the-summit',
#  'www.tvnetwork.com/mount-everest-beyond-the-summit-season-1',
#  'stream.myshow.tv/wonders-of-the-coral-reef-new',
#  'stream.watchhub.org/wonders-of-the-coral-reef-preview',
#  'watch.myshow.tv/wonders-of-the-coral-reef-new',
#  'watch.streamit.net/wonders-of-the-coral-reef?ref=source2',
#  'watch.myshow.tv/wonders-of-the-coral-reef-preview',
#  'watch.myshow.tv/wonders-of-the-coral-reef-special',
#  'watch.watchhub.org/wonders-of-the-coral-reef-free-trial',
#  'stream.tvnetwork.com/vintage-noir-tales-of-the-50s?utm_campaign=ad33',
#  'stream.tvnetwork.com/vintage-noir-tales-of-the-50s-season-1',
#  'www.example.com/vintage-noir-tales-of-the-50s',
#  'hub.tvnetwork.com/vintage-noir-tales-of-the-50s-season-1',
#  'view.watchhub.org/vintage-noir-tales-of-the-50s-exclusive',
#  'www.streamit.net/vintage-noir-tales-of-the-50s',
#  'view.example.com/vintage-noir-tales-of-the-50s-season-1',
#  'media.watchhub.org/vintage-noir-tales-of-the-50s-new',
#  'stream.watchhub.org/vintage-noir-tales-of-the-50s-new',
#  'stream.tvnetwork.com/vintage-noir-tales-of-the-50s?utm_campaign=ad33',
#  'hub.myshow.tv/hollywood-gold-the-best-of-the-silver-screen-new',
#  'www.watchhub.org/hollywood-gold-the-best-of-the-silver-screen?utm_campaign=ad33',
#  'watch.watchhub.org/hollywood-gold-the-best-of-the-silver-screen?utm_campaign=ad33',
#  'view.watchhub.org/hollywood-gold-the-best-of-the-silver-screen?ref=source2',
#  'watch.example.com/hollywood-gold-the-best-of-the-silver-screen?utm_campaign=ad33',
#  'online.tvnetwork.com/the-golden-age-of-television-exclusive',
#  'stream.example.com/the-golden-age-of-television-new',
#  'www.streamit.net/the-golden-age-of-television-special',
#  'view.watchhub.org/the-golden-age-of-television?utm_campaign=ad33',
#  'www.tvnetwork.com/the-golden-age-of-television-episode-guide',
#  'hub.watchhub.org/classic-cartoons-rewind-preview',
#  'hub.example.com/classic-cartoons-rewind-new',
#  'stream.tvnetwork.com/classic-cartoons-rewind-special',
#  'stream.tvnetwork.com/classic-cartoons-rewind-exclusive',
#  'online.watchhub.org/classic-cartoons-rewind-free-trial',
#  'media.myshow.tv/classic-cartoons-rewind?ref=source2',
#  'view.example.com/classic-cartoons-rewind-preview',
#  'online.streamit.net/classic-cartoons-rewind?utm_campaign=ad33',
#  'media.example.com/classic-cartoons-rewind-episode-guide',
#  'watch.tvnetwork.com/classic-cartoons-rewind-preview',
#  'view.streamit.net/heroes-of-the-west-old-cowboy-adventures-special',
#  'hub.streamit.net/heroes-of-the-west-old-cowboy-adventures?ref=source2',
#  'watch.watchhub.org/heroes-of-the-west-old-cowboy-adventures-free-trial',
#  'media.watchhub.org/heroes-of-the-west-old-cowboy-adventures?ref=source2',
#  'media.tvnetwork.com/heroes-of-the-west-old-cowboy-adventures-preview',
#  'hub.watchhub.org/the-big-picture-cinemas-finest-years-free-trial',
#  'view.myshow.tv/the-big-picture-cinemas-finest-years-preview',
#  'online.myshow.tv/the-big-picture-cinemas-finest-years-season-1',
#  'online.myshow.tv/the-big-picture-cinemas-finest-years-new',
#  'stream.example.com/the-big-picture-cinemas-finest-years-special',
#  'hub.tvnetwork.com/the-big-picture-cinemas-finest-years-preview',
#  'hub.streamit.net/the-big-picture-cinemas-finest-years-new',
#  'hub.myshow.tv/the-big-picture-cinemas-finest-years-free-trial',
#  'watch.watchhub.org/love-in-black-and-white-romantic-classics',
#  'online.example.com/love-in-black-and-white-romantic-classics-preview',
#  'hub.example.com/love-in-black-and-white-romantic-classics-new',
#  'online.example.com/love-in-black-and-white-romantic-classics',
#  'watch.tvnetwork.com/love-in-black-and-white-romantic-classics-exclusive',
#  'online.tvnetwork.com/love-in-black-and-white-romantic-classics?ref=source2',
#  'hub.example.com/love-in-black-and-white-romantic-classics-free-trial',
#  'www.watchhub.org/love-in-black-and-white-romantic-classics',
#  'www.myshow.tv/love-in-black-and-white-romantic-classics-preview',
#  'hub.tvnetwork.com/retro-sci-fi-space-and-beyond?utm_campaign=ad33',
#  'www.myshow.tv/retro-sci-fi-space-and-beyond-free-trial',
#  'media.tvnetwork.com/retro-sci-fi-space-and-beyond?utm_campaign=ad33',
#  'hub.myshow.tv/retro-sci-fi-space-and-beyond-new',
#  'view.watchhub.org/retro-sci-fi-space-and-beyond',
#  'watch.example.com/timeless-thrillers-hitchcocks-legacy-episode-guide',
#  'view.streamit.net/timeless-thrillers-hitchcocks-legacy-preview',
#  'online.myshow.tv/timeless-thrillers-hitchcocks-legacy?utm_campaign=ad33',
#  'watch.example.com/timeless-thrillers-hitchcocks-legacy?ref=source2',
#  'view.myshow.tv/timeless-thrillers-hitchcocks-legacy?utm_campaign=ad33',
#  'online.tvnetwork.com/timeless-thrillers-hitchcocks-legacy-special',
#  'stream.streamit.net/timeless-thrillers-hitchcocks-legacy-preview',
#  'www.example.com/timeless-thrillers-hitchcocks-legacy-special',
#  'watch.tvnetwork.com/timeless-thrillers-hitchcocks-legacy?ref=source2',
#  'hub.watchhub.org/timeless-thrillers-hitchcocks-legacy-special',
#  'watch.streamit.net/1950s-sitcom-showcase-preview',
#  'online.example.com/1950s-sitcom-showcase-special',
#  'watch.tvnetwork.com/1950s-sitcom-showcase-preview',
#  'hub.example.com/1950s-sitcom-showcase-season-1',
#  'stream.tvnetwork.com/1950s-sitcom-showcase-free-trial',
#  'media.example.com/1950s-sitcom-showcase?utm_campaign=ad33',
#  'stream.watchhub.org/1950s-sitcom-showcase',
#  'online.streamit.net/1950s-sitcom-showcase?ref=source2',
#  'media.streamit.net/1950s-sitcom-showcase-season-1',
#  'online.example.com/1950s-sitcom-showcase',
#  'online.streamit.net/the-forgotten-kingdom-episode-guide',
#  'watch.streamit.net/the-forgotten-kingdom?utm_campaign=ad33',
#  'view.tvnetwork.com/the-forgotten-kingdom-episode-guide',
#  'stream.tvnetwork.com/the-forgotten-kingdom-preview',
#  'watch.tvnetwork.com/the-forgotten-kingdom-new',
#  'hub.example.com/unwritten-laws-exclusive',
#  'online.streamit.net/unwritten-laws-episode-guide',
#  'stream.watchhub.org/unwritten-laws',
#  'watch.watchhub.org/unwritten-laws?ref=source2',
#  'watch.example.com/unwritten-laws?utm_campaign=ad33',
#  'online.watchhub.org/echoes-of-the-past-exclusive',
#  'view.myshow.tv/echoes-of-the-past',
#  'hub.example.com/echoes-of-the-past-preview',
#  'watch.tvnetwork.com/echoes-of-the-past-exclusive',
#  'hub.watchhub.org/echoes-of-the-past-season-1',
#  'view.example.com/echoes-of-the-past-exclusive',
#  'hub.example.com/echoes-of-the-past',
#  'media.myshow.tv/echoes-of-the-past-special',
#  'hub.watchhub.org/echoes-of-the-past?utm_campaign=ad33',
#  'hub.myshow.tv/echoes-of-the-past-free-trial',
#  'stream.example.com/shattered-mirror-a-tale-of-betrayal-free-trial',
#  'online.watchhub.org/shattered-mirror-a-tale-of-betrayal-free-trial',
#  'media.streamit.net/shattered-mirror-a-tale-of-betrayal-episode-guide',
#  'stream.example.com/shattered-mirror-a-tale-of-betrayal-exclusive',
#  'stream.myshow.tv/shattered-mirror-a-tale-of-betrayal-special',
#  'online.tvnetwork.com/lies-beneath-the-surface-special',
#  'media.example.com/lies-beneath-the-surface-season-1',
#  'media.tvnetwork.com/lies-beneath-the-surface?utm_campaign=ad33',
#  'www.streamit.net/lies-beneath-the-surface-free-trial',
#  'stream.watchhub.org/lies-beneath-the-surface?ref=source2',
#  'www.myshow.tv/after-the-storm-a-familys-battle-special',
#  'hub.example.com/after-the-storm-a-familys-battle?utm_campaign=ad33',
#  'online.myshow.tv/after-the-storm-a-familys-battle-special',
#  'media.example.com/after-the-storm-a-familys-battle?utm_campaign=ad33',
#  'view.tvnetwork.com/after-the-storm-a-familys-battle-episode-guide',
#  'www.watchhub.org/after-the-storm-a-familys-battle',
#  'hub.tvnetwork.com/after-the-storm-a-familys-battle-episode-guide',
#  'hub.streamit.net/in-the-shadow-of-giants',
#  'media.watchhub.org/in-the-shadow-of-giants-preview',
#  'www.myshow.tv/in-the-shadow-of-giants-season-1',
#  'media.streamit.net/in-the-shadow-of-giants-season-1',
#  'www.streamit.net/in-the-shadow-of-giants-special',
#  'stream.example.com/in-the-shadow-of-giants-special',
#  'hub.streamit.net/fallen-crown-the-battle-for-the-throne-preview',
#  'www.myshow.tv/fallen-crown-the-battle-for-the-throne-exclusive',
#  'www.watchhub.org/fallen-crown-the-battle-for-the-throne?utm_campaign=ad33',
#  'media.myshow.tv/fallen-crown-the-battle-for-the-throne-season-1',
#  'www.example.com/fallen-crown-the-battle-for-the-throne',
#  'hub.streamit.net/fallen-crown-the-battle-for-the-throne-season-1',
#  'www.streamit.net/fallen-crown-the-battle-for-the-throne-preview',
#  'media.watchhub.org/fallen-crown-the-battle-for-the-throne-exclusive',
#  'online.myshow.tv/fallen-crown-the-battle-for-the-throne-season-1',
#  'hub.example.com/fallen-crown-the-battle-for-the-throne-special',
#  'www.watchhub.org/last-sunset-a-dystopian-love-story?ref=source2',
#  'online.myshow.tv/last-sunset-a-dystopian-love-story',
#  'watch.myshow.tv/last-sunset-a-dystopian-love-story?utm_campaign=ad33',
#  'hub.myshow.tv/last-sunset-a-dystopian-love-story-exclusive',
#  'online.example.com/last-sunset-a-dystopian-love-story?ref=source2',
#  'view.example.com/last-sunset-a-dystopian-love-story?utm_campaign=ad33',
#  'online.tvnetwork.com/last-sunset-a-dystopian-love-story-preview',
#  'watch.streamit.net/last-sunset-a-dystopian-love-story?ref=source2',
#  'online.example.com/last-sunset-a-dystopian-love-story-preview',
#  'stream.example.com/whispers-in-the-dark',
#  'stream.watchhub.org/whispers-in-the-dark',
#  'watch.example.com/whispers-in-the-dark-season-1',
#  'view.tvnetwork.com/whispers-in-the-dark-free-trial',
#  'online.myshow.tv/whispers-in-the-dark?ref=source2',
#  'stream.watchhub.org/whispers-in-the-dark-special',
#  'hub.tvnetwork.com/whispers-in-the-dark-preview',
#  'hub.myshow.tv/whispers-in-the-dark-exclusive',
#  'hub.watchhub.org/whispers-in-the-dark?utm_campaign=ad33']

# %%
#Online Content Data
def generate_fake_online_content(demo_df, num_online_content_records, all_urls):
    fake = Faker('en_US')
    Faker.seed(42)
    random.seed(42)
    
    ids = demo_df['ID'].tolist()
    
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2024, 12, 31)
     
#     start_date = datetime(2022, 1,1, 0, 0, 0)
#     end_date = datetime(2024, 12, 31, 21, 59, 59)

    online_content_data = []
    for _ in range(num_online_content_records):
        id_ = random.choice(ids)
        date = fake.date_between(start_date = start_date, end_date = end_date)
        url = random.choice(all_urls) #sample urls from all_urls
        
        
        online_content_data.append({
            'ID': id_, 
            'DATE': date,
            'URL': url,
            'SCORE': None
        })
        
    mean = 0.5
    std_dev = 0.2
    scores = np.random.normal(loc = mean, scale=std_dev, size = num_online_content_records)
    scores = np.clip(scores, 0.0, 1.0)
    
#     for i in range(len(online_content_data)):
#         online_content_data[i]['SCORE'] = scores[i]
    
    for record, score in zip(online_content_data, scores):
        record['SCORE'] = score
        
    online_content_data = pd.DataFrame(online_content_data)
    return online_content_data

# %%
num_online_content_records = 100000

online_content_df = generate_fake_online_content(demo_df, num_online_content_records, all_urls)

# %%
len(online_content_df['ID'].unique())
# Out:
# 1000

# %%
online_content_df
# Out:
#         ID        DATE                                                URL  \
# 0      655  2024-09-20  watch.watchhub.org/fitness-gurus-transformatio...
# 1       26  2022-06-22         online.watchhub.org/flight-risk-free-trial
# 2      251  2022-02-08   stream.tvnetwork.com/target-locked-episode-guide
# 3      143  2023-03-04  media.watchhub.org/living-large-luxury-homes-e...
# 4      693  2023-01-16   watch.streamit.net/1950s-sitcom-showcase-preview
# ...    ...         ...                                                ...
# 99995  901  2024-11-24  view.streamit.net/timeless-thrillers-hitchcock...
# 99996  440  2022-04-09  online.example.com/nomads-of-the-north-life-in...
# 99997  331  2024-05-11           online.example.com/1950s-sitcom-showcase
# 99998   79  2024-09-02   watch.streamit.net/1950s-sitcom-showcase-preview
# 99999  664  2023-09-20  www.tvnetwork.com/unseen-worlds-microscopic-ma...
#
#           SCORE
# 0      0.834853
# 1      0.508279
# 2      0.738272
# 3      0.447552
# 4      0.102237
# ...         ...
# 99995  0.735416
# 99996  0.353572
# 99997  0.502180
# 99998  0.516853
# 99999  0.537815
#
# [100000 rows x 4 columns]

# %%
#date(2024, 12, 31)

# %% [markdown]
# ## Subscription Data

# %%
#Subscription Data 
#ID, BRAND, SUB START/SUB END (instead of start date?), TERM, STATUS  
#instead of replicating data, can just give them preprocessed data:
 #ie one ID per BRAND, start date, end date, resubscriber flag, frequnecy, current term, status
